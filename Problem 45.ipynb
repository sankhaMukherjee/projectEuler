# %% [markdown]
# # Problem 45: Triangular, pentagonal, and hexagonal
#
#
#
# Triangle, pentagonal, and hexagonal numbers are generated by the following formulae:
# - Triangle 	  	$T_n=n(n+1)/2$ 	  	1, 3, 6, 10, 15, ...
# - Pentagonal 	  	$P_n=n(3n−1)/2$ 	  	1, 5, 12, 22, 35, ...
# - Hexagonal 	    $H_n=n(2n−1$) 	  	1, 6, 15, 28, 45, ...
#
# It can be verified that $T_{285} = P_{165} = H_{143} = 40755$.
#
# Find the next triangle number that is also pentagonal and hexagonal.

# %%
from math import sqrt

# %%
def isPentagonal(Pn:int)-> bool:
    
    toCheck = (sqrt(1 + 24*Pn)+1)/6
    if toCheck == int(toCheck):
        return True
    
    return False

# %%
def isHexagonal(Hn:int)-> bool:
    
    toCheck = (sqrt(1 + 8*Hn)+1)/4
    if toCheck == int(toCheck):
        return True
    
    return False

# %%
# %%time
n = 286
while True:
    Tn = n*(n+1)//2
    n += 1
    if not isPentagonal(Tn): continue
    if not isHexagonal(Tn): continue
    
    print(Tn)
    break
# Out:
# 1533776805
# CPU times: user 40.1 ms, sys: 0 ns, total: 40.1 ms
# Wall time: 38.7 ms

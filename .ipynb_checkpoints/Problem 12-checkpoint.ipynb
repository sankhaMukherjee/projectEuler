# %% [markdown]
# # Problem 12: Highly divisible triangular number
#
#
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be `1 + 2 + 3 + 4 + 5 + 6 + 7 = 28`. The first ten terms would be:
#
# `1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...`
#
# Let us list the factors of the first seven triangle numbers:
#
#      1: 1
#      3: 1,3
#      6: 1,2,3,6
#     10: 1,2,5,10
#     15: 1,3,5,15
#     21: 1,3,7,21
#     28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
N = 7
N * (N+1)/2
# Out:
# 28.0

# %%
import numpy as np
import math

def primeFactors(N, primes):
    
    factors = []
    
    for p in primes:
        if p > N: break
        if N % p == 0:
            factors.append( p )
    
    return factors

def primeFactorsAndExp(N, primes):
    factors = {}
    
    for p in primes:
        if p > N: break
        Nfactors = 0
        while N % p == 0:    
            Nfactors += 1
            N /= p
        if Nfactors > 0:
            factors[p] = Nfactors
    
    return factors

# %%
f = primeFactorsAndExp(28, primes)

# %%
def nDivisors(N, primes):
    f = primeFactorsAndExp(N, primes)
    nDivisors = np.prod( [(_+1) for _ in f.values()])
    return nDivisors

# %%
from tqdm import tqdm

# %%
f1 = primeFactorsAndExp(2, primes) 

for m in tqdm(list(range(2, 100000))):
    
    f2 =  primeFactorsAndExp(m+1, primes)
    f3 = {}
    f3.update( f1 )
    for k, v in f2.items():
        if k in f3:
            f3[k] += v
        else:
            f3[k] = v
       
    if f3[2] == 1:
        del(f3[2])
    else:
        f3[2] -= 1
    f1 = f2
    
    d = np.prod( [(_+1) for _ in f3.values()])
    if d > 500:
        print(m, m*(m+1)//2, d)
        break
    
    #print('-----------------')
    #print(m, f3, d)
# Out:
#  12%|█▏        | 12373/99998 [00:02<00:15, 5833.66it/s]
# 12375 76576500 576

# %%
n, d
# Out:
# (49995000, 240)

# %% [markdown]
# # Appendix A : A set of primes

# %%
import numpy as np

# %%
# Find a set of (at least) 500 primes
largeN = 500000
nums = np.linspace(2, largeN, largeN-1).astype(int)

primes = []
while len(nums) > 0:
    p = nums[0]
    primes.append(p)
    nums = nums[ nums % p != 0 ]

# %%
len(primes)
# Out:
# 41538
